# %%
from mcf2swc import *

from swctools import SWCModel, FrustaSet, PointSet, plot_model

import logging

logging.basicConfig(level=logging.DEBUG)

import os

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %%
spine_idx = 2
mcf_qst = 0.6
mcf_mcst = 5
obj_name = f"TS{spine_idx}"
polylines_name = f"TS{spine_idx}_qst{mcf_qst}_mcst{mcf_mcst}"
mm = MeshManager(mesh_path=f"../data/mesh/processed/{obj_name}_simplified.obj")
skel = SkeletonGraph.from_txt(f"../data/mcf_skeletons/{polylines_name}.polylines.txt")
print(skel)
# pls.prune_short_branches_inplace(min_length=10)
mm.visualize_mesh_3d(skel=skel)
# Out:
# INFO:mcf2swc.mesh:Loaded mesh: 508 vertices, 1016 faces
# SkeletonGraph with 119 nodes and 119 edges
