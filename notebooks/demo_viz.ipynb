# %%
import sys, os
sys.path.append(os.path.abspath('..'))

from mcf2swc import show_swc

import pyvista as pv
pv.set_jupyter_backend("trame")

show_swc("../data/swc/TS2_trace_section_median.swc")
# Out:
# Widget(value='<iframe src="http://localhost:59911/index.html?ui=P_0x2183b6417c0_0&reconnect=auto" class="pyvis…

# %%
show_swc("../data/swc/TS2_trace_equivalent_area.swc")
# Out:
# Widget(value='<iframe src="http://localhost:59911/index.html?ui=P_0x2183d5b6690_1&reconnect=auto" class="pyvis…

# %%
show_swc("../data/swc/TS2_trace_equivalent_perimeter.swc")
# Out:
# Widget(value='<iframe src="http://localhost:59911/index.html?ui=P_0x21876fe69f0_2&reconnect=auto" class="pyvis…

# %%
show_swc("../data/swc/TS2_trace_nearest_surface.swc")
# Out:
# Widget(value='<iframe src="http://localhost:59911/index.html?ui=P_0x2183bc86810_3&reconnect=auto" class="pyvis…

# %%
show_swc("../data/swc/TS2_trace_section_circle_fit.swc")
# Out:
# Widget(value='<iframe src="http://localhost:59911/index.html?ui=P_0x2183db9ec90_4&reconnect=auto" class="pyvis…
