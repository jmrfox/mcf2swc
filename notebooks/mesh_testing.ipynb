# %%
import pymeshlab
from mcf2swc.path import *
add_project_dir_to_path()
print(data_path("mesh/raw/TS2_alone.obj"))
# Out:
# C:\Users\jordan\Documents\GitHub\mcf2swc\data\mesh\raw\TS2_alone.obj

# %%
ms = pymeshlab.MeshSet()
ms.load_new_mesh(str(data_path("mesh/raw/TS2_alone.obj")))

# Clean up potential issues
# ms.apply_filter('meshing_remove_duplicate_faces')
# ms.apply_filter('meshing_remove_duplicate_vertices')

# Fill holes
# ms.apply_filter('meshing_close_holes')

# If holes remain or are complex, consider alpha wrapping
ms.apply_filter('generate_alpha_wrap')

ms.save_current_mesh(str(data_path("mesh/TS2_test.obj")))

# %%
# view mesh
from mcf2swc import MeshManager
import trimesh

mesh = trimesh.load(data_path("mesh/TS2_test.obj"))
mm = MeshManager(mesh=mesh)
mm.visualize_mesh_3d()

# %%
def process_mesh(filepath_raw, filename_wrapped):
    print(f"Processing {filepath_raw}")
    ms = pymeshlab.MeshSet()
    ms.load_new_mesh(str(filepath_raw))

    # Clean up potential issues
    ms.apply_filter('meshing_remove_duplicate_faces')
    ms.apply_filter('meshing_remove_duplicate_vertices')

    # Fill holes
    # ms.apply_filter('meshing_close_holes')

    # If holes remain or are complex, consider alpha wrapping
    ms.apply_filter('generate_alpha_wrap')

    ms.save_current_mesh(str(filename_wrapped))

ts_numbers = [1, 2, 3, 4, 21, 24, 48, 67, 76]
for n in ts_numbers:
    filepath_raw = data_path(f"mesh/raw/TS{n}_alone.obj")
    filename_wrapped = data_path(f"mesh/processed/TS{n}_wrapped.obj")
    process_mesh(filepath_raw, filename_wrapped)
# Out:
# Processing C:\Users\jordan\Documents\GitHub\mcf2swc\data\mesh\raw\TS1_alone.obj
# Processing C:\Users\jordan\Documents\GitHub\mcf2swc\data\mesh\raw\TS2_alone.obj
# Processing C:\Users\jordan\Documents\GitHub\mcf2swc\data\mesh\raw\TS3_alone.obj
# Processing C:\Users\jordan\Documents\GitHub\mcf2swc\data\mesh\raw\TS4_alone.obj
# Processing C:\Users\jordan\Documents\GitHub\mcf2swc\data\mesh\raw\TS21_alone.obj
# Processing C:\Users\jordan\Documents\GitHub\mcf2swc\data\mesh\raw\TS24_alone.obj
# Processing C:\Users\jordan\Documents\GitHub\mcf2swc\data\mesh\raw\TS48_alone.obj
# Processing C:\Users\jordan\Documents\GitHub\mcf2swc\data\mesh\raw\TS67_alone.obj
# Processing C:\Users\jordan\Documents\GitHub\mcf2swc\data\mesh\raw\TS76_alone.obj

# %%
mesh = trimesh.load(data_path("mesh/processed/TS1_wrapped.obj"))
mm = MeshManager(mesh)
mm.visualize_mesh_3d()
